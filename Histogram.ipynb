# %%
import matplotlib.pyplot as plt
# Sample data: a small set of values
data = [5, 7, 7, 8, 9, 10, 10, 10, 11,11.5, 12,13,13,]
# Create the histogram
plt.hist(data, bins=10, edgecolor='Pink')
# Set the title and labels for the plot
plt. title('Simple Histogram Example')
plt. xlabel( 'Numbers')
plt. ylabel ( 'Count')
# Show the plot
plt. show()

# %%
import matplotlib.pyplot as plt
# Sample data: a small set of values
data = [5, 7, 7, 8, 9, 10, 10, 10, 11, 12]
# Create the histogram
plt.hist(data, bins=7, edgecolor='black')
# Set the title and labels for the plot
plt. title('Simple Histogram Example')
plt. xlabel( 'Value')
plt. ylabel ( 'Frequency')
# Show the plot
plt. show()

# %%
import matplotlib.pyplot as plt
import numpy as np
np.random.seed(42)
data = np.random.randint(5,81,1000)
plt.hist(data,bins=15,edgecolor='yellow',color='black')
plt. title('Histogram of CANCER Patients Age Distribution')
plt. xlabel( 'Value')
plt. ylabel ( 'Frequency')
plt. show()

# %%
import pandas as pa import seaborn as sns
import matplotlib.pyplot as plt
# Sample data
data = {
    'semester': ['Sem 1', 'Sem 1', 'Sem 1', 'Sem 1', 'Sem 1', 'Sem 2', 'Sem 2', 'Sem 2', 'Sem 2', 'Sem 2'],
    'hours_studied': [5, 8, 10, 4, 6, 9, 11, 7, 12, 8]
}
# Create a DataFrame
df = pd. DataFrame(data)
# Create the boxplot
plt. figure(figsize=(8, 6))
sns.boxplot(x='semester', y='hours_studied', data=df)
# Set plot labels and title
plt. title( 'Student Performance: Hours Studied by Semester') 
plt. xlabel( 'Semester')
plt. ylabel( 'Number of Hours Studied')
